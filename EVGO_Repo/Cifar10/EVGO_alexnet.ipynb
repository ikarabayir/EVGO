# %%
from __future__ import division

seed_value= 0

import os
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import tensorflow as tf
tf.set_random_seed(seed_value)
from keras import backend as K
import os
import keras
import pickle
import os.path
#import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LambdaCallback
from keras.callbacks import TensorBoard
from sklearn.preprocessing import LabelBinarizer
from keras import initializers
from keras.layers import Input
import keras.backend as K
from keras.models import Model
from keras import backend as K
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator


# Hyperparameters
batch_size = 128
num_classes = 10
epochs = 200


# Load CIFAR10 Data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()


# convert to one hot encoing 
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
K.set_image_dim_ordering('tf')

K.image_dim_ordering(), x_train.shape


def build_model(setseed):
    """
    Builds test Keras model for Alexnet CIFAR-10
    :param loss (str): Type of loss - must be one of Keras accepted keras losses
    :return: Keras dense model of predefined structure
    """
    input = Input(shape=[32, 32,3])
    conv1 = Conv2D(48, (3,3), strides=(2,2), activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(input)
    mp1 = MaxPooling2D(pool_size=(2, 2), strides=(2,2))(conv1)
    ban1 = BatchNormalization()(mp1)
    
    conv2 = Conv2D(96, (3,3), activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(ban1)
    mp2 = MaxPooling2D(pool_size=(3, 3), strides=(2,2))(conv2)
    ban2 = BatchNormalization()(mp2)    
    
    conv3 = Conv2D(192, (3,3), activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(ban2)
    conv4 = Conv2D(192, (3,3), activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(conv3)
    conv5 = Conv2D(256, (3,3), activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(conv4)
    
    mp3 = MaxPooling2D(pool_size=(3, 3), strides=(2,2))(conv5)
    ban3 = BatchNormalization()(mp3) 
    flat= Flatten()(ban3)
    dens1=Dense(512, activation='tanh', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(flat)
    drop1=Dropout(0.5)(dens1)
    dens2=Dense(256, activation='tanh', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(drop1)
    drop2=Dropout(0.5)(dens2)   
    probs=Dense(num_classes, activation='softmax', kernel_initializer=initializers.glorot_uniform(seed = setseed), bias_initializer=initializers.glorot_uniform(seed = setseed))(drop2)
    
    model = Model(input=input, output=probs)
    model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics = ['accuracy'])

    return model



all_model = [None,None,None]
losses = [None,None,None]

prediction=[]

all_score =[0,0,0]
gr=[]
wr=[]
xwr=[]

for i in range(3):
    np.random.seed(25+i)
    model = build_model(i+2)
    all_model[i]=model
    
for i in range(3):    
    weights = all_model[i].trainable_weights # weight tensors
    weights = [weight for weight in weights] # filter down weights tensors to only ones which are trainable
    gradients = all_model[i].optimizer.get_gradients(all_model[i].total_loss, weights) # gradient tensors
    gr.append(gradients)
    wr.append(weights)
    xweights = all_model[i].non_trainable_weights # weight tensors
    xweights = [weight for weight in xweights] # filter down weights tensors to only ones which are trainable
    xwr.append(xweights)

    losses[i]=all_model[i].total_loss
    prediction.append(all_model[i].output)
    
    
model.summary()

input_tensors = [all_model[0].inputs[0], # input data
                 all_model[0].sample_weights[0], # how much to weight each sample by
                 all_model[0].targets[0], # labels
                 K.learning_phase(), # train or test mode
                 all_model[1].inputs[0], # input data
                 all_model[1].sample_weights[0], # how much to weight each sample by
                 all_model[1].targets[0], # labels
                 all_model[2].inputs[0], # input data
                 all_model[2].sample_weights[0], # how much to weight each sample by
                 all_model[2].targets[0], # labels
                ]

minlos = K.argmin(losses)

grr=[]
for x in gr:
    for y in x:
        grr.append(y)

upd_test= K.function(inputs=input_tensors, outputs=[ losses[0], losses[1], losses[2], minlos, prediction[0], prediction[1], prediction[2] ])





grad_best=[]
grad_non0 = []
grad_non1 = []


weig_best=[]
weig_non0 = []
weig_non1 = []

xweig_best=[]
xweig_non0 = []
xweig_non1 = []




for i in range(len(gr[0])):
    gr_ck=tf.concat([gr[0][i],gr[1][i], gr[2][i]],0)
    newshape = (3, ) + (tuple(wr[0][i].shape))

    
    gr_ck2=tf.reshape(gr_ck, newshape)
    
    bb = gr_ck2[minlos]
    grad_best.append(bb)
    
    nbb0 = gr_ck2[0:minlos]                       #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
    nbb1 = gr_ck2[minlos+1:]                      #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
    nbc = tf.concat([nbb0,nbb1], 0)    
    nbc = tf.reshape(nbc, (-1,))
    newshape2 = (2, ) + (tuple(wr[0][i].shape))
    
    nbc2 = tf.reshape(nbc, newshape2) 
    nb0 = nbc2[0]
    nb1 = nbc2[1]
    grad_non0.append(nb0)
    grad_non1.append(nb1)
    

    wr_ck=tf.concat([wr[0][i],wr[1][i], wr[2][i]],0)
    
    newshape = (3, ) + (tuple(wr[0][i].shape))
    wr_ck2=tf.reshape(wr_ck, newshape) 
    bb2 = wr_ck2[minlos]
    weig_best.append(bb2)
    
    #wb = wr_ck[minlos]
    wnbb0 = wr_ck2[0:minlos]                       #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
    wnbb1 = wr_ck2[minlos+1:]                      #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
    wnbc = tf.concat([wnbb0,wnbb1],0)    
    wnbc = tf.reshape(wnbc, (-1,))
    newshape2 = (2, ) + (tuple(wr[0][i].shape))
    
    wnbc2 =tf.reshape(wnbc, newshape2)
    wnb0 = wnbc2[0]
    wnb1 = wnbc2[1]
    weig_non0.append(wnb0)
    weig_non1.append(wnb1)
    
    if i<len(xwr[0]):
        print (i)
        xwr_ck=tf.concat([xwr[0][i],xwr[1][i], xwr[2][i]], 0)

        newshape = (3, ) + (tuple(xwr[0][i].shape))
        
        xwr_ck2=tf.reshape(xwr_ck, newshape)  
        xbb2 = xwr_ck2[minlos]
        xweig_best.append(xbb2)

        #wb = wr_ck[minlos]
        xwnbb0 = xwr_ck2[0:minlos]                       #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
        xwnbb1 = xwr_ck2[minlos+1:]                      #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
        xwnbc = tf.concat([xwnbb0,xwnbb1], 0)    
        
        xwnbc = tf.reshape(xwnbc, (-1,))
        newshape2 = (2, ) + (tuple(xwr[0][i].shape))
         
        xwnbc2 = tf.reshape(xwnbc, newshape2) 
        xwnb0 = xwnbc2[0]
        xwnb1 = xwnbc2[1]
        xweig_non0.append(xwnb0)
        xweig_non1.append(xwnb1)
    else:
        pass

los=tf.stack([losses[0], losses[1], losses[2]])

newshape = (3, )
los2=tf.reshape(los, newshape) 
losbest = los2[minlos]

#wb = wr_ck[minlos]
los_0 = los2[0:minlos]                       #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
los_1 = los2[minlos+1:]                      #[0,enk) U (enk,] araliklarinin birlesimi bize nonbesti verecek
loswnbc = tf.concat([los_0,los_1],0)    
loswnbc = tf.reshape(loswnbc,(-1,))
newshape2 = (2, )

loswnbc2 = tf.reshape(loswnbc, newshape2)
losss0 = loswnbc2[0]
losss1 = loswnbc2[1]


eps = 1.5

mn0 = [tf.keras.backend.l2_normalize((best-nonbest)*(losbest-losss0)/tf.reduce_sum( tf.pow((best-nonbest),2)+eps))   for best, nonbest in zip(weig_best, weig_non0)]

mn1 = [tf.keras.backend.l2_normalize((best-nonbest)*(losbest-losss1)/tf.reduce_sum( tf.pow((best-nonbest),2)+eps))   for best, nonbest in zip(weig_best, weig_non1)]


lr=0.1

nCom0 = [non- lr* grad - lr/10 * mn for mn, grad, non in zip(mn0,grad_non0, weig_non0 )]

nCom1 = [non- lr* grad - lr/10 * mn for mn, grad, non in zip(mn1,grad_non1, weig_non1 )]

xbest = [ -lr * nc + non for nc, non in zip(grad_best, weig_best)]

upd2 = [
    tf.assign(param_i, v)
    for param_i, v in zip(wr[2], xbest)
]

upd2.extend(
        [tf.assign(param_i, v)
        for param_i, v in zip(xwr[2], xweig_best)]
    )

upd2.extend(
        [tf.assign(param_i, v)
        for param_i, v in zip(wr[1], nCom0)]
    )
upd2.extend(
        [tf.assign(param_i, v)
        for param_i, v in zip(xwr[1], xweig_non0)]
    )
upd2.extend(
        [tf.assign(param_i, v)
        for param_i, v in zip(wr[0], nCom1)]
    )
upd2.extend(
        [tf.assign(param_i, v)
        for param_i, v in zip(xwr[0], xweig_non1)]
    )


upd_bb2= K.function(inputs=input_tensors, outputs=[ losses[0], losses[1], losses[2], minlos, prediction[0], prediction[1], prediction[2] ], updates=upd2)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255


datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    zca_epsilon=1e-06,  # epsilon for ZCA whitening
    rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
    # randomly shift images horizontally (fraction of total width)
    width_shift_range=0.1,
    # randomly shift images vertically (fraction of total height)
    height_shift_range=0.1,
    shear_range=0.,  # set range for random shear
    zoom_range=0.,  # set range for random zoom
    channel_shift_range=0.,  # set range for random channel shifts
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    cval=0.,  # value used for fill_mode = "constant"
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None)

# Compute quantities required for feature-wise normalization
# (std, mean, and principal components if ZCA whitening is applied).
datagen.fit(x_train)

datagentest = ImageDataGenerator()

# alfa 0.1 beta 0.5 for nonbest, 0.1 alfa for best
from sklearn.metrics import accuracy_score

lossepoch=[]
lossepoch_test=[]
lossx=[]
acctra=[]
loss_test=[]
acc_test=[]
skip=[]

for f in range(200):
    tr1=[]
    tr2=[]
    res1=[]
    res2=[]
    print('Epoch', f)
    print ('train')
    batches = 0
    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=batch_size):
        K.set_learning_phase(1)
        for i in range(len(all_model)):
            all_model[i].layers[14].rate= 0.5
            all_model[i].layers[16].rate= 0.5
        inputs = [x_batch, # X
                  np.ones(y_batch.shape[0]), # sample weights
                  y_batch, # y
                  1, # learning phase in TEST mode
                  x_batch, # X
                  np.ones(y_batch.shape[0]), # sample weights
                  y_batch, # y
                  x_batch, # X
                  np.ones(y_batch.shape[0]), # sample weights
                  y_batch, # y
                 ]
        ll = upd_bb2(inputs)
        yhat=ll[6]
        lossepoch.append(ll[2])
        tr1.append(ll[2])
        tr2.append(accuracy_score(np.argmax(y_batch,axis=1), np.argmax(yhat,axis=1)))
        skip.append(ll[3])
        batches += 1
        if batches > len(x_train) / batch_size:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break
    m=(len(x_train) / batch_size)-int((len(x_train) / batch_size))
    tr1[-1]*=m
    tr2[-1]*=m
    lossx.append(np.mean(tr1))
    acctra.append(np.mean(tr2))
    print ('train loss score is :'+str(np.mean(tr1)))
    print ('train acc score is :'+str(np.mean(tr2)))
    print ('test')
    batchesx = 0
    for x_batch, y_batch in datagentest.flow(x_test, y_test, batch_size=batch_size):
        K.set_learning_phase(0)
        for i in range(len(all_model)):
            all_model[i].layers[14].rate= 0
            all_model[i].layers[16].rate= 0
        inputs = [x_batch, # X
                  np.ones(y_batch.shape[0]), # sample weights
                  y_batch, # y
                  1, # learning phase in TEST mode
                  x_batch, # X
                  np.ones(y_batch.shape[0]), # sample weights
                  y_batch, # y
                  x_batch, # X
                  np.ones(y_batch.shape[0]), # sample weights
                  y_batch, # y
                 ]
        ll = upd_test(inputs)
        yhat=ll[6]
        lossepoch_test.append(ll[2])
        res1.append(ll[2])
        res2.append(accuracy_score(np.argmax(y_batch,axis=1), np.argmax(yhat,axis=1)))
        batchesx += 1
        if batchesx >= len(x_test) / batch_size:
            break
    m=(len(x_test) / batch_size)-int((len(x_test) / batch_size))
    res1[-1]*=m
    res2[-1]*=m
    loss_test.append(np.mean(res1))
    acc_test.append(np.mean(res2))
    print ('test loss score is :'+str(np.mean(res1)))
    print ('test acc score is :'+str(np.mean(res2)))

print (np.max(acc_test), np.argmax(acc_test))
print (np.min(loss_test), np.argmin(loss_test))
print (np.min(lossx), np.argmin(lossx))


np.savetxt("alg4_1_lossepoch_reducesum.csv", lossepoch, delimiter=",", fmt='%s')
np.savetxt("alg4_1_lossepoch_test_reducesum.csv", lossepoch_test, delimiter=",", fmt='%s')
np.savetxt("alg4_1_loss_tra_reducesum.csv", lossx, delimiter=",", fmt='%s')
np.savetxt("alg4_1_skip_reducesum.csv", skip, delimiter=",", fmt='%s')
np.savetxt("alg4_1_acc_tra_reducesum.csv", acctra, delimiter=",", fmt='%s')
np.savetxt("alg4_1_loss_test_reducesum.csv", loss_test, delimiter=",", fmt='%s')
np.savetxt("alg4_1_acc_test_reducesum.csv", acc_test, delimiter=",", fmt='%s')
# Out:
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:83: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# WARNING:tensorflow:From C:\Users\ikarabayir\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 48)        1344
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 48)          0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 48)          192
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 96)          41568
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 3, 3, 96)          0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 3, 96)          384
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 3, 3, 192)         166080
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 3, 3, 192)         331968
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 3, 3, 256)         442624
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,250,666
# Trainable params: 1,249,866
# Non-trainable params: 800
# _________________________________________________________________
# 0
# 1
# 2
# 3
# 4
# 5
# Epoch 0
# train
# train loss score is :1.6601321321466695
# train acc score is :0.40654971227621484
# test
# test loss score is :1.3926316135669057
# test acc score is :0.4892207278481013
# Epoch 1
# train
# train loss score is :1.3025964859425259
# train acc score is :0.5350063938618926
# test
# test loss score is :1.2435351944045177
# test acc score is :0.5476661392405063
# Epoch 2
# train
# train loss score is :1.1522112759711491
# train acc score is :0.5958080242966752
# test
# test loss score is :1.0342466623722752
# test acc score is :0.6220332278481012
# Epoch 3
# train
# train loss score is :1.046384574545314
# train acc score is :0.63443094629156
# test
# test loss score is :0.9340938348558885
# test acc score is :0.6617879746835443
# Epoch 4
# train
# train loss score is :0.9772167438665009
# train acc score is :0.6611053388746803
# test
# test loss score is :0.8993758432850053
# test acc score is :0.6798852848101266
# Epoch 5
# train
# train loss score is :0.9087408236835314
# train acc score is :0.682604699488491
# test
# test loss score is :0.8724237808698341
# test acc score is :0.685818829113924
# Epoch 6
# train
# train loss score is :0.8548066051834075
# train acc score is :0.7034047314578005
# test
# test loss score is :0.8280515446315838
# test acc score is :0.7067840189873418
# Epoch 7
# train
# train loss score is :0.8060278131452667
# train acc score is :0.7224464514066496
# test
# test loss score is :0.8001813182159315
# test acc score is :0.7154865506329114
# Epoch 8
# train
# train loss score is :0.7728753421274598
# train acc score is :0.7329563618925832
# test
# test loss score is :0.7823731318304811
# test acc score is :0.7195411392405063
# Epoch 9
# train
# train loss score is :0.7405869856743557
# train acc score is :0.7471427429667519
# test
# test loss score is :0.7885207709255098
# test acc score is :0.7175632911392406
# Epoch 10
# train
# train loss score is :0.7131944293027643
# train acc score is :0.7555946291560103
# test
# test loss score is :0.700002555982976
# test acc score is :0.7515822784810127
# Epoch 11
# train
# train loss score is :0.6880160673042698
# train acc score is :0.7630274936061381
# test
# test loss score is :0.7241960219755957
# test acc score is :0.7458465189873418
# Epoch 12
# train
# train loss score is :0.6610884945792006
# train acc score is :0.7720588235294118
# test
# test loss score is :0.7104842155417309
# test acc score is :0.7495055379746836
# Epoch 13
# train
# train loss score is :0.6467541264527289
# train acc score is :0.7768941815856778
# test
# test loss score is :0.6953300397041478
# test acc score is :0.7569224683544303
# Epoch 14
# train
# train loss score is :0.6197519384496047
# train acc score is :0.787264226342711
# test
# test loss score is :0.6774366940312748
# test acc score is :0.7613726265822784
# Epoch 15
# train
# train loss score is :0.6124901798127405
# train acc score is :0.7882033248081841
# test
# test loss score is :0.6797005195595041
# test acc score is :0.7605814873417721
# Epoch 16
# train
# train loss score is :0.5862644314194274
# train acc score is :0.8003516624040921
# test
# test loss score is :0.6741221942290475
# test acc score is :0.765625
# Epoch 17
# train
# train loss score is :0.5702482953172205
# train acc score is :0.8037084398976982
# test
# test loss score is :0.6718573021360591
# test acc score is :0.7644382911392406
# Epoch 18
# train
# train loss score is :0.5577884947647677
# train acc score is :0.8084039322250639
# test
# test loss score is :0.6764867285007163
# test acc score is :0.7641416139240507
# Epoch 19
# train
# train loss score is :0.5409381689356111
# train acc score is :0.8147578324808185
# test
# test loss score is :0.6492751259592515
# test acc score is :0.7740308544303798
# Epoch 20
# train
# train loss score is :0.5280537185690287
# train acc score is :0.8182344948849105
# test
# test loss score is :0.6414209646703322
# test acc score is :0.7767009493670886
# Epoch 21
# train
# train loss score is :0.5167487579900438
# train acc score is :0.8225703324808185
# test
# test loss score is :0.6278924411044845
# test acc score is :0.7813488924050633
# Epoch 22
# train
# train loss score is :0.5083617914248916
# train acc score is :0.8262468030690537
# test
# test loss score is :0.6428927818808374
# test acc score is :0.7784810126582279
# Epoch 23
# train
# train loss score is :0.4960564091382429
# train acc score is :0.8289841751918159
# test
# test loss score is :0.6325911856904815
# test acc score is :0.7792721518987342
# Epoch 24
# train
# train loss score is :0.4778664906216247
# train acc score is :0.8366168478260869
# test
# test loss score is :0.6339438233194472
# test acc score is :0.7769976265822784
# Epoch 25
# train
# train loss score is :0.4695018163651152
# train acc score is :0.8388946611253197
# test
# test loss score is :0.6346517510806458
# test acc score is :0.7814477848101266
# Epoch 26
# train
# train loss score is :0.45909616006228626
# train acc score is :0.8418518222506394
# test
# test loss score is :0.6069279924223695
# test acc score is :0.7936115506329114
# Epoch 27
# train
# train loss score is :0.4529001957848859
# train acc score is :0.8432105179028133
# test
# test loss score is :0.6395549434649793
# test acc score is :0.7828322784810127
# Epoch 28
# train
# train loss score is :0.4373690892496835
# train acc score is :0.8493046675191815
# test
# test loss score is :0.6506507973882216
# test acc score is :0.7787776898734177
# Epoch 29
# train
# train loss score is :0.4273067004121173
# train acc score is :0.8517822890025576
# test
# test loss score is :0.6520471213550507
# test acc score is :0.7830300632911392
# Epoch 30
# train
# train loss score is :0.4241087306433779
# train acc score is :0.854479699488491
# test
# test loss score is :0.6481508799368823
# test acc score is :0.7807555379746836
# Epoch 31
# train
# train loss score is :0.41139981500289935
# train acc score is :0.8583160166240409
# test
# test loss score is :0.6232237509817262
# test acc score is :0.7912381329113924
# Epoch 32
# train
# train loss score is :0.4061118119093768
# train acc score is :0.858016304347826
# test
# test loss score is :0.6318811072578913
# test acc score is :0.7879746835443038
# Epoch 33
# train
# train loss score is :0.3928273649281248
# train acc score is :0.8648697250639387
# test
# test loss score is :0.6213684238587753
# test acc score is :0.7925237341772152
# Epoch 34
# train
# train loss score is :0.38903715295712354
# train acc score is :0.8641104539641944
# test
# test loss score is :0.6540499848749819
# test acc score is :0.7852056962025317
# Epoch 35
# train
# train loss score is :0.37821815889852733
# train acc score is :0.8691855818414322
# test
# test loss score is :0.6366369604498525
# test acc score is :0.7880735759493671
# Epoch 36
# train
# train loss score is :0.369144075076141
# train acc score is :0.8733615728900256
# test
# test loss score is :0.6589198816048948
# test acc score is :0.7840189873417721
# Epoch 37
# train
# train loss score is :0.36562737693910097
# train acc score is :0.8734215153452686
# test
# test loss score is :0.6459922942839846
# test acc score is :0.7847112341772152
# Epoch 38
# train
# train loss score is :0.35154233893851183
# train acc score is :0.8773177749360613
# test
# test loss score is :0.6547865269682075
# test acc score is :0.7857001582278481
# Epoch 39
# train
# train loss score is :0.34479514038776193
# train acc score is :0.8808543797953964
# test
# test loss score is :0.6266379183205434
# test acc score is :0.795193829113924
# Epoch 40
# train
# train loss score is :0.33513330979763395
# train acc score is :0.8845907928388747
# test
# test loss score is :0.6365257552530192
# test acc score is :0.7911392405063291
# Epoch 41
# train
# train loss score is :0.33446876168289147
# train acc score is :0.8847106777493606
# test
# test loss score is :0.6523933780344227
# test acc score is :0.788370253164557
# Epoch 42
# train
# train loss score is :0.3256587623368444
# train acc score is :0.888946611253197
# test
# test loss score is :0.6481777787019934
# test acc score is :0.7908425632911392
# Epoch 43
# train
# train loss score is :0.31840475143678965
# train acc score is :0.8899256713554987
# test
# test loss score is :0.6404801207252696
# test acc score is :0.7946993670886076
# Epoch 44
# train
# train loss score is :0.3147827399241955
# train acc score is :0.8915041560102301
# test
# test loss score is :0.678526146879679
# test acc score is :0.786689082278481
# Epoch 45
# train
# train loss score is :0.30747394720116233
# train acc score is :0.8926031010230179
# test
# test loss score is :0.6678058875701095
# test acc score is :0.7923259493670886
# Epoch 46
# train
# train loss score is :0.30442438804356337
# train acc score is :0.8944013746803069
# test
# test loss score is :0.6567936142600035
# test acc score is :0.7929193037974683
# Epoch 47
# train
# train loss score is :0.2934391183726242
# train acc score is :0.8981377877237852
# test
# test loss score is :0.6760290708345703
# test acc score is :0.7889636075949367
# Epoch 48
# train
# train loss score is :0.2930387954234772
# train acc score is :0.8982976342710998
# test
# test loss score is :0.6697028852716277
# test acc score is :0.7847112341772152
# Epoch 49
# train
# train loss score is :0.2859506696996177
# train acc score is :0.9011748721227621
# test
# test loss score is :0.6530266558822198
# test acc score is :0.7956882911392406
# Epoch 50
# train
# train loss score is :0.2777691471397572
# train acc score is :0.9031130115089514
# test
# test loss score is :0.6650131605093992
# test acc score is :0.791435917721519
# Epoch 51
# train
# train loss score is :0.27789868280062896
# train acc score is :0.9035925511508951
# test
# test loss score is :0.6511916907952179
# test acc score is :0.7982594936708861
# Epoch 52
# train
# train loss score is :0.2634145544694208
# train acc score is :0.9076286764705882
# test
# test loss score is :0.6665606602460523
# test acc score is :0.789754746835443
# Epoch 53
# train
# train loss score is :0.2609501594672804
# train acc score is :0.909846547314578
# test
# test loss score is :0.6735793611954285
# test acc score is :0.797567246835443
# Epoch 54
# train
# train loss score is :0.2598085204506164
# train acc score is :0.9103660485933504
# test
# test loss score is :0.669594364971677
# test acc score is :0.7959849683544303
# Epoch 55
# train
# train loss score is :0.25456114564938925
# train acc score is :0.9122842071611253
# test
# test loss score is :0.6782667065345789
# test acc score is :0.7952927215189873
# Epoch 56
# train
# train loss score is :0.25028615468717597
# train acc score is :0.9122242647058824
# test
# test loss score is :0.6895933668070202
# test acc score is :0.7887658227848101
# Epoch 57
# train
# train loss score is :0.24592060839657284
# train acc score is :0.9137028452685422
# test
# test loss score is :0.6858276866753644
# test acc score is :0.795193829113924
# Epoch 58
# train
# train loss score is :0.23668390349544527
# train acc score is :0.918897858056266
# test
# test loss score is :0.6858337782794917
# test acc score is :0.7981606012658228
# Epoch 59
# train
# train loss score is :0.2408764399873936
# train acc score is :0.9168598145780051
# test
# test loss score is :0.7045893157962002
# test acc score is :0.7916337025316456
# Epoch 60
# train
# train loss score is :0.2308202044338064
# train acc score is :0.9201566496163683
# test
# test loss score is :0.676170010732699
# test acc score is :0.7964794303797469
# Epoch 61
# train
# train loss score is :0.22982648395173386
# train acc score is :0.9192175511508951
# test
# test loss score is :0.7103334050389785
# test acc score is :0.7926226265822784
# Epoch 62
# train
# train loss score is :0.222854525755967
# train acc score is :0.9225943094629157
# test
# test loss score is :0.7127764644690707
# test acc score is :0.7908425632911392
# Epoch 63
# train
# train loss score is :0.21834109290538695
# train acc score is :0.9241727941176471
# test
# test loss score is :0.6898209943047052
# test acc score is :0.7986550632911392
# Epoch 64
# train
# train loss score is :0.21959767405353392
# train acc score is :0.92349344629156
# test
# test loss score is :0.7075392353006557
# test acc score is :0.7941060126582279
# Epoch 65
# train
# train loss score is :0.2136885204526317
# train acc score is :0.9251918158567775
# test
# test loss score is :0.696364523489264
# test acc score is :0.7948971518987342
# Epoch 66
# train
# train loss score is :0.20911763037752618
# train acc score is :0.9274696291560103
# test
# test loss score is :0.7118519963342932
# test acc score is :0.7956882911392406
# Epoch 67
# train
# train loss score is :0.2085297990237813
# train acc score is :0.9279891304347826
# test
# test loss score is :0.6993612430612498
# test acc score is :0.7987539556962026
# Epoch 68
# train
# train loss score is :0.2018736825536584
# train acc score is :0.9292079603580563
# test
# test loss score is :0.7198183842097656
# test acc score is :0.7963805379746836
# Epoch 69
# train
# train loss score is :0.20306675984045428
# train acc score is :0.9308064258312021
# test
# test loss score is :0.69977187487898
# test acc score is :0.7993473101265823
# Epoch 70
# train
# train loss score is :0.20073817850416883
# train acc score is :0.9308463874680307
# test
# test loss score is :0.7357224037375631
# test acc score is :0.7892602848101266
# Epoch 71
# train
# train loss score is :0.19375669332149695
# train acc score is :0.9329243925831202
# test
# test loss score is :0.7473315794633913
# test acc score is :0.7898536392405063
# Epoch 72
# train
# train loss score is :0.18826289323951734
# train acc score is :0.9338235294117647
# test
# test loss score is :0.7233535430476635
# test acc score is :0.796182753164557
# Epoch 73
# train
# train loss score is :0.18713410525485072
# train acc score is :0.9348425511508951
# test
# test loss score is :0.7712669172618962
# test acc score is :0.7891613924050633
# Epoch 74
# train
# train loss score is :0.18872842479430502
# train acc score is :0.934343030690537
# test
# test loss score is :0.7415483707114111
# test acc score is :0.7976661392405063
# Epoch 75
# train
# train loss score is :0.18185595723102466
# train acc score is :0.9365209398976982
# test
# test loss score is :0.7354743618376648
# test acc score is :0.7981606012658228
# Epoch 76
# train
# train loss score is :0.17768416714752117
# train acc score is :0.9390185421994884
# test
# test loss score is :0.7007219182162345
# test acc score is :0.8034018987341772
# Epoch 77
# train
# train loss score is :0.17568795829820816
# train acc score is :0.9403372762148338
# test
# test loss score is :0.733464931338271
# test acc score is :0.7965783227848101
# Epoch 78
# train
# train loss score is :0.17086373146651956
# train acc score is :0.9412164322250639
# test
# test loss score is :0.7443957662657846
# test acc score is :0.792128164556962
# Epoch 79
# train
# train loss score is :0.1679704390142275
# train acc score is :0.9415361253196931
# test
# test loss score is :0.7461228050008605
# test acc score is :0.7905458860759493
# Epoch 80
# train
# train loss score is :0.16842089817309014
# train acc score is :0.9415960677749361
# test
# test loss score is :0.7211353697731525
# test acc score is :0.7989517405063291
# Epoch 81
# train
# train loss score is :0.16736053633491707
# train acc score is :0.9425151854219949
# test
# test loss score is :0.7317944746228713
# test acc score is :0.7993473101265823
# Epoch 82
# train
# train loss score is :0.1603221704092477
# train acc score is :0.9449328644501279
# test
# test loss score is :0.7440172958223126
# test acc score is :0.7983583860759493
# Epoch 83
# train
# train loss score is :0.15243673744751973
# train acc score is :0.946611253196931
# test
# test loss score is :0.7464529559770717
# test acc score is :0.7998417721518988
# Epoch 84
# train
# train loss score is :0.15941172686722271
# train acc score is :0.944013746803069
# test
# test loss score is :0.7278558936300157
# test acc score is :0.7997428797468354
# Epoch 85
# train
# train loss score is :0.15722451804925108
# train acc score is :0.9451326726342711
# test
# test loss score is :0.7329773846306379
# test acc score is :0.8048852848101266
# Epoch 86
# train
# train loss score is :0.15137081676165162
# train acc score is :0.9479899296675192
# test
# test loss score is :0.7512698860108098
# test acc score is :0.7964794303797469
# Epoch 87
# train
# train loss score is :0.1519500250544618
# train acc score is :0.9467511189258312
# test
# test loss score is :0.7442562146277367
# test acc score is :0.8019185126582279
# Epoch 88
# train
# train loss score is :0.15226685453939925
# train acc score is :0.9473105818414322
# test
# test loss score is :0.7417569121793856
# test acc score is :0.7982594936708861
# Epoch 89
# train
# train loss score is :0.1494657614165941
# train acc score is :0.9478900255754475
# test
# test loss score is :0.7453266600076156
# test acc score is :0.7998417721518988
# Epoch 90
# train
# train loss score is :0.148688397720418
# train acc score is :0.9484494884910486
# test
# test loss score is :0.7570379964912994
# test acc score is :0.8002373417721519
# Epoch 91
# train
# train loss score is :0.14686108383890764
# train acc score is :0.9491288363171355
# test
# test loss score is :0.7543003170550624
# test acc score is :0.7998417721518988
# Epoch 92
# train
# train loss score is :0.1401905047604838
# train acc score is :0.9496882992327366
# test
# test loss score is :0.7534443771914591
# test acc score is :0.8032041139240507
# Epoch 93
# train
# train loss score is :0.14358342861485146
# train acc score is :0.949968030690537
# test
# test loss score is :0.7591950828798965
# test acc score is :0.8005340189873418
# Epoch 94
# train
# train loss score is :0.1389460670082923
# train acc score is :0.9516064578005116
# test
# test loss score is :0.7707888113358353
# test acc score is :0.8000395569620253
# Epoch 95
# train
# train loss score is :0.13721984806363388
# train acc score is :0.9522258631713555
# test
# test loss score is :0.776407281620593
# test acc score is :0.8002373417721519
# Epoch 96
# train
# train loss score is :0.13325680356444147
# train acc score is :0.9540441176470589
# test
# test loss score is :0.775509105264386
# test acc score is :0.7995450949367089
# Epoch 97
# train
# train loss score is :0.13166827870451886
# train acc score is :0.9540241368286445
# test
# test loss score is :0.7788502185405055
# test acc score is :0.7974683544303798
# Epoch 98
# train
# train loss score is :0.13818833896475832
# train acc score is :0.951886189258312
# test
# test loss score is :0.7642851996270916
# test acc score is :0.8006329113924051
# Epoch 99
# train
# train loss score is :0.1290366874478967
# train acc score is :0.9559223145780051
# test
# test loss score is :0.8010340292902687
# test acc score is :0.7949960443037974
# Epoch 100
# train
# train loss score is :0.12902225843628348
# train acc score is :0.9550431585677749
# test
# test loss score is :0.7750746820923649
# test acc score is :0.8001384493670886
# Epoch 101
# train
# train loss score is :0.12494774748478323
# train acc score is :0.9558623721227621
# test
# test loss score is :0.7921667851601975
# test acc score is :0.7971716772151899
# Epoch 102
# train
# train loss score is :0.12290453764102648
# train acc score is :0.9577605498721228
# test
# test loss score is :0.795069247389896
# test acc score is :0.8020174050632911
# Epoch 103
# train
# train loss score is :0.1215596352096485
# train acc score is :0.9579203964194374
# test
# test loss score is :0.7991577639609952
# test acc score is :0.8002373417721519
# Epoch 104
# train
# train loss score is :0.13031385201112847
# train acc score is :0.9539641943734015
# test
# test loss score is :0.7703061813158514
# test acc score is :0.8038963607594937
# Epoch 105
# train
# train loss score is :0.12067667668080315
# train acc score is :0.9583399936061381
# test
# test loss score is :0.781000246164165
# test acc score is :0.8035996835443038
# Epoch 106
# train
# train loss score is :0.12007038090902064
# train acc score is :0.9584398976982097
# test
# test loss score is :0.7613546126345291
# test acc score is :0.8028085443037974
# Epoch 107
# train
# train loss score is :0.11976822448508515
# train acc score is :0.9582001278772379
# test
# test loss score is :0.7778845357744
# test acc score is :0.8029074367088608
# Epoch 108
# train
# train loss score is :0.11397912661018579
# train acc score is :0.9599584398976982
# test
# test loss score is :0.7820873077062866
# test acc score is :0.8021162974683544
# Epoch 109
# train
# train loss score is :0.11625195156468456
# train acc score is :0.959638746803069
# test
# test loss score is :0.8084002551681633
# test acc score is :0.7998417721518988
# Epoch 110
# train
# train loss score is :0.11091596775514352
# train acc score is :0.962176310741688
# test
# test loss score is :0.8008914820472651
# test acc score is :0.7988528481012658
# Epoch 111
# train
# train loss score is :0.11490576414157973
# train acc score is :0.9596187659846548
# test
# test loss score is :0.7801444134380244
# test acc score is :0.799940664556962
# Epoch 112
# train
# train loss score is :0.11167408807484237
# train acc score is :0.9606977301790282
# test
# test loss score is :0.8161757709104803
# test acc score is :0.7988528481012658
# Epoch 113
# train
# train loss score is :0.10724614023485833
# train acc score is :0.9632952365728901
# test
# test loss score is :0.8084430026857159
# test acc score is :0.8009295886075949
# Epoch 114
# train
# train loss score is :0.11105601095577793
# train acc score is :0.9607576726342711
# test
# test loss score is :0.8134279856576195
# test acc score is :0.8007318037974683
# Epoch 115
# train
# train loss score is :0.10831025386910381
# train acc score is :0.9631753516624041
# test
# test loss score is :0.7889565921423933
# test acc score is :0.8049841772151899
# Epoch 116
# train
# train loss score is :0.10545955084816878
# train acc score is :0.9634550831202046
# test
# test loss score is :0.8226185256167303
# test acc score is :0.7942049050632911
# Epoch 117
# train
# train loss score is :0.10395859306096993
# train acc score is :0.9635749680306905
# test
# test loss score is :0.7953326739842379
# test acc score is :0.8027096518987342
# Epoch 118
# train
# train loss score is :0.10408792057362816
# train acc score is :0.9634550831202046
# test
# test loss score is :0.818172042458495
# test acc score is :0.7954905063291139
# Epoch 119
# train
# train loss score is :0.10382038056183501
# train acc score is :0.9631753516624041
# test
# test loss score is :0.7838892177501812
# test acc score is :0.8057753164556962
# Epoch 120
# train
# train loss score is :0.10071557227169614
# train acc score is :0.9648137787723785
# test
# test loss score is :0.8377016778988174
# test acc score is :0.7988528481012658
# Epoch 121
# train
# train loss score is :0.10319172266079947
# train acc score is :0.9640545076726342
# test
# test loss score is :0.8055137761786014
# test acc score is :0.8000395569620253
# Epoch 122
# train
# train loss score is :0.09449704556875979
# train acc score is :0.9672314578005116
# test
# test loss score is :0.8255868778575824
# test acc score is :0.8049841772151899
# Epoch 123
# train
# train loss score is :0.09795658066249488
# train acc score is :0.9662324168797954
# test
# test loss score is :0.8228600380730026
# test acc score is :0.8017207278481012
# Epoch 124
# train
# train loss score is :0.09796324607861392
# train acc score is :0.9664122442455243
# test
# test loss score is :0.8350947248407558
# test acc score is :0.7996439873417721
# Epoch 125
# train
# train loss score is :0.09473360904380489
# train acc score is :0.9664721867007673
# test
# test loss score is :0.822848423938208
# test acc score is :0.8041930379746836
# Epoch 126
# train
# train loss score is :0.09712900784905151
# train acc score is :0.9659926470588235
# test
# test loss score is :0.80184580470565
# test acc score is :0.8081487341772152
# Epoch 127
# train
# train loss score is :0.09682181974529953
# train acc score is :0.9666120524296675
# test
# test loss score is :0.8173591413452655
# test acc score is :0.8020174050632911
# Epoch 128
# train
# train loss score is :0.09483712391875436
# train acc score is :0.9667718989769821
# test
# test loss score is :0.8385534636393378
# test acc score is :0.8014240506329114
# Epoch 129
# train
# train loss score is :0.09737523618247122
# train acc score is :0.965213395140665
# test
# test loss score is :0.8227473997239825
# test acc score is :0.8054786392405063
# Epoch 130
# train
# train loss score is :0.09545917619291283
# train acc score is :0.9671515345268542
# test
# test loss score is :0.8028360756137704
# test acc score is :0.8055775316455697
# Epoch 131
# train
# train loss score is :0.09325276607947658
# train acc score is :0.9677909207161125
# test
# test loss score is :0.8186311346443393
# test acc score is :0.8091376582278481
# Epoch 132
# train
# train loss score is :0.08783163445646805
# train acc score is :0.9694493286445013
# test
# test loss score is :0.8243947296957427
# test acc score is :0.8022151898734177
# Epoch 133
# train
# train loss score is :0.09607258237317166
# train acc score is :0.967391304347826
# test
# test loss score is :0.820295611608632
# test acc score is :0.8049841772151899
# Epoch 134
# train
# train loss score is :0.08670632666229364
# train acc score is :0.9701686381074168
# test
# test loss score is :0.8327487816538992
# test acc score is :0.8036985759493671
# Epoch 135
# train
# train loss score is :0.08955311579177218
# train acc score is :0.968809942455243
# test
# test loss score is :0.8294147590198849
# test acc score is :0.806368670886076
# Epoch 136
# train
# train loss score is :0.08786584944714365
# train acc score is :0.9699488491048593
# test
# test loss score is :0.8312102854251862
# test acc score is :0.8055775316455697
# Epoch 137
# train
# train loss score is :0.08874431477569024
# train acc score is :0.96875
# test
# test loss score is :0.8307809387392635
# test acc score is :0.7990506329113924
# Epoch 138
# train
# train loss score is :0.083037257313614
# train acc score is :0.9712276214833759
# test
# test loss score is :0.836933938291254
# test acc score is :0.8020174050632911
# Epoch 139
# train
# train loss score is :0.08542018267742889
# train acc score is :0.9697490409207161
# test
# test loss score is :0.8169746745990801
# test acc score is :0.8069620253164557
# Epoch 140
# train
# train loss score is :0.08973985571709588
# train acc score is :0.9689098465473146
# test
# test loss score is :0.844778053934061
# test acc score is :0.7988528481012658
# Epoch 141
# train
# train loss score is :0.08304307086255087
# train acc score is :0.9714274296675192
# test
# test loss score is :0.8381719478889357
# test acc score is :0.8059731012658228
# Epoch 142
# train
# train loss score is :0.0808527415935093
# train acc score is :0.9711476982097187
# test
# test loss score is :0.8244310160980949
# test acc score is :0.807753164556962
# Epoch 143
# train
# train loss score is :0.07860136001377993
# train acc score is :0.9724464514066496
# test
# test loss score is :0.8298726498467636
# test acc score is :0.8035996835443038
# Epoch 144
# train
# train loss score is :0.08096848823168241
# train acc score is :0.9721667199488491
# test
# test loss score is :0.8479423051393484
# test acc score is :0.8044897151898734
# Epoch 145
# train
# train loss score is :0.08282219661194878
# train acc score is :0.9716272378516624
# test
# test loss score is :0.8401425925991203
# test acc score is :0.802314082278481
# Epoch 146
# train
# train loss score is :0.08485345186575143
# train acc score is :0.9696491368286445
# test
# test loss score is :0.828295497200157
# test acc score is :0.7991495253164557
# Epoch 147
# train
# train loss score is :0.0786622084970193
# train acc score is :0.9722666240409207
# test
# test loss score is :0.8590215603007546
# test acc score is :0.7995450949367089
# Epoch 148
# train
# train loss score is :0.07552998799406697
# train acc score is :0.9738650895140665
# test
# test loss score is :0.8414053913158707
# test acc score is :0.8014240506329114
# Epoch 149
# train
# train loss score is :0.07544980225774943
# train acc score is :0.9736053388746803
# test
# test loss score is :0.8423116222212587
# test acc score is :0.8051819620253164
# Epoch 150
# train
# train loss score is :0.0797181911623615
# train acc score is :0.9719868925831202
# test
# test loss score is :0.8620691204773663
# test acc score is :0.8006329113924051
# Epoch 151
# train
# train loss score is :0.07619865961572932
# train acc score is :0.9726862212276215
# test
# test loss score is :0.8732002362420287
# test acc score is :0.8024129746835443
# Epoch 152
# train
# train loss score is :0.07875825607341708
# train acc score is :0.972406489769821
# test
# test loss score is :0.8484090483700267
# test acc score is :0.8068631329113924
# Epoch 153
# train
# train loss score is :0.07437459073360543
# train acc score is :0.9737651854219949
# test
# test loss score is :0.8495462938577314
# test acc score is :0.8044897151898734
# Epoch 154
# train
# train loss score is :0.078619004617257
# train acc score is :0.9726262787723785
# test
# test loss score is :0.8320541732673403
# test acc score is :0.8031052215189873
# Epoch 155
# train
# train loss score is :0.07173048683901882
# train acc score is :0.9758232097186701
# test
# test loss score is :0.8319145425493959
# test acc score is :0.8050830696202531
# Epoch 156
# train
# train loss score is :0.0728434436880719
# train acc score is :0.9749040920716112
# test
# test loss score is :0.8475195923938027
# test acc score is :0.8064675632911392
# Epoch 157
# train
# train loss score is :0.07221713391801966
# train acc score is :0.9744844948849105
# test
# test loss score is :0.8614195181599146
# test acc score is :0.8025118670886076
# Epoch 158
# train
# train loss score is :0.07172224624439731
# train acc score is :0.9747842071611253
# test
# test loss score is :0.873011888488184
# test acc score is :0.8015229430379747
# Epoch 159
# train
# train loss score is :0.07611558507756351
# train acc score is :0.9738650895140665
# test
# test loss score is :0.8655986702894862
# test acc score is :0.8041930379746836
# Epoch 160
# train
# train loss score is :0.07356349447780215
# train acc score is :0.9746243606138107
# test
# test loss score is :0.8896930606304845
# test acc score is :0.7994462025316456
# Epoch 161
# train
# train loss score is :0.06641228273725304
# train acc score is :0.9764625959079284
# test
# test loss score is :0.8832632329645036
# test acc score is :0.8036985759493671
# Epoch 162
# train
# train loss score is :0.07183956789255352
# train acc score is :0.9757033248081841
# test
# test loss score is :0.8790407488712028
# test acc score is :0.8022151898734177
# Epoch 163
# train
# train loss score is :0.06752911152894539
# train acc score is :0.9762627877237852
# test
# test loss score is :0.8749584281652034
# test acc score is :0.8021162974683544
# Epoch 164
# train
# train loss score is :0.06483483295697157
# train acc score is :0.9770620204603581
# test
# test loss score is :0.8838156884229635
# test acc score is :0.8040941455696202
# Epoch 165
# train
# train loss score is :0.0702375501794431
# train acc score is :0.9761029411764706
# test
# test loss score is :0.8997419523664668
# test acc score is :0.8050830696202531
# Epoch 166
# train
# train loss score is :0.06575418313455475
# train acc score is :0.9768422314578005
# test
# test loss score is :0.8734224130269848
# test acc score is :0.8087420886075949
# Epoch 167
# train
# train loss score is :0.0710818419695053
# train acc score is :0.9746643222506394
# test
# test loss score is :0.8731638838218737
# test acc score is :0.8071598101265823
# Epoch 168
# train
# train loss score is :0.06960955417960349
# train acc score is :0.9759630754475703
# test
# test loss score is :0.8795224792217906
# test acc score is :0.8025118670886076
# Epoch 169
# train
# train loss score is :0.06974238248260888
# train acc score is :0.9763427109974424
# test
# test loss score is :0.887868430229682
# test acc score is :0.7969738924050633
# Epoch 170
# train
# train loss score is :0.066303596693708
# train acc score is :0.9768222506393862
# test
# test loss score is :0.8791945522998849
# test acc score is :0.8064675632911392
# Epoch 171
# train
# train loss score is :0.06479884987420705
# train acc score is :0.9763626918158568
# test
# test loss score is :0.8855163522913486
# test acc score is :0.8051819620253164
# Epoch 172
# train
# train loss score is :0.0674837254085447
# train acc score is :0.975943094629156
# test
# test loss score is :0.8819698504632032
# test acc score is :0.8000395569620253
# Epoch 173
# train
# train loss score is :0.065747507128512
# train acc score is :0.9766624040920716
# test
# test loss score is :0.8724062646491618
# test acc score is :0.8034018987341772
# Epoch 174
# train
# train loss score is :0.06336282232664335
# train acc score is :0.9783407928388747
# test
# test loss score is :0.8833763420204573
# test acc score is :0.8078520569620253
# Epoch 175
# train
# train loss score is :0.06820644589993731
# train acc score is :0.9763427109974424
# test
# test loss score is :0.8990279253147826
# test acc score is :0.7987539556962026
# Epoch 176
# train
# train loss score is :0.06548433686437471
# train acc score is :0.976682384910486
# test
# test loss score is :0.8980957074444506
# test acc score is :0.8007318037974683
# Epoch 177
# train
# train loss score is :0.06181245845030336
# train acc score is :0.9780410805626598
# test
# test loss score is :0.8763634411594535
# test acc score is :0.8032041139240507
# Epoch 178
# train
# train loss score is :0.06123147278790698
# train acc score is :0.9781409846547314
# test
# test loss score is :0.9099571678457381
# test acc score is :0.8006329113924051
# Epoch 179
# train
# train loss score is :0.06380885150497946
# train acc score is :0.9776614450127877
# test
# test loss score is :0.8947598315492461
# test acc score is :0.8090387658227848
# Epoch 180
# train
# train loss score is :0.0629545979313743
# train acc score is :0.977801310741688
# test
# test loss score is :0.8885264828612532
# test acc score is :0.8092365506329114
# Epoch 181
# train
# train loss score is :0.058138675840042744
# train acc score is :0.9786005434782609
# test
# test loss score is :0.879897375838666
# test acc score is :0.8068631329113924
# Epoch 182
# train
# train loss score is :0.057188698966854044
# train acc score is :0.9794397378516624
# test
# test loss score is :0.8719745847997786
# test acc score is :0.8089398734177216
# Epoch 183
# train
# train loss score is :0.06431132647902002
# train acc score is :0.9773017902813299
# test
# test loss score is :0.8634251482501815
# test acc score is :0.8057753164556962
# Epoch 184
# train
# train loss score is :0.06233894557018033
# train acc score is :0.9782608695652174
# test
# test loss score is :0.9037862831278692
# test acc score is :0.8035007911392406
# Epoch 185
# train
# train loss score is :0.0588726989562859
# train acc score is :0.9793198529411765
# test
# test loss score is :0.9147319552264636
# test acc score is :0.805379746835443
# Epoch 186
# train
# train loss score is :0.05929178907119138
# train acc score is :0.9794197570332481
# test
# test loss score is :0.8943423849495151
# test acc score is :0.8073575949367089
# Epoch 187
# train
# train loss score is :0.05838518673458787
# train acc score is :0.9797794117647058
# test
# test loss score is :0.8744037163597119
# test acc score is :0.8073575949367089
# Epoch 188
# train
# train loss score is :0.05823295810105055
# train acc score is :0.9794597186700768
# test
# test loss score is :0.8923987429353255
# test acc score is :0.8056764240506329
# Epoch 189
# train
# train loss score is :0.058165751392250435
# train acc score is :0.9792998721227621
# test
# test loss score is :0.888687751196985
# test acc score is :0.8054786392405063
# Epoch 190
# train
# train loss score is :0.05546384228749529
# train acc score is :0.9799392583120204
# test
# test loss score is :0.9032287663674052
# test acc score is :0.8055775316455697
# Epoch 191
# train
# train loss score is :0.05949201886935155
# train acc score is :0.9794996803069054
# test
# test loss score is :0.8915351082252551
# test acc score is :0.8043908227848101
# Epoch 192
# train
# train loss score is :0.05673646613183762
# train acc score is :0.9798193734015346
# test
# test loss score is :0.9097401925091502
# test acc score is :0.8025118670886076
# Epoch 193
# train
# train loss score is :0.056144024393118705
# train acc score is :0.9798593350383632
# test
# test loss score is :0.9234071185317221
# test acc score is :0.8033030063291139
# Epoch 194
# train
# train loss score is :0.06180024208308048
# train acc score is :0.97818094629156
# test
# test loss score is :0.8951564193526401
# test acc score is :0.8074564873417721
# Epoch 195
# train
# train loss score is :0.05242171717728453
# train acc score is :0.9809782608695652
# test
# test loss score is :0.9040039707965488
# test acc score is :0.8085443037974683
# Epoch 196
# train
# train loss score is :0.05501068910033635
# train acc score is :0.9806385869565217
# test
# test loss score is :0.9311556320024442
# test acc score is :0.8014240506329114
# Epoch 197
# train
# train loss score is :0.05382054668846433
# train acc score is :0.9801990089514067
# test
# test loss score is :0.9193794357625744
# test acc score is :0.8041930379746836
# Epoch 198
# train
# train loss score is :0.054697617076223004
# train acc score is :0.9803988171355499
# test
# test loss score is :0.9311494933842104
# test acc score is :0.8045886075949367
# Epoch 199
# train
# train loss score is :0.053420411120347504
# train acc score is :0.9811181265984654
# test
# test loss score is :0.9244489383093918
# test acc score is :0.8042919303797469
# 0.8092365506329114 180
# 0.6069279924223695 26
# 0.05242171717728453 195
